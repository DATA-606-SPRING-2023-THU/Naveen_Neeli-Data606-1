# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import sys

# %% [markdown]
# ## Loading Data

# %%
filelist = ['taxi_202201.csv','taxi_202201.csv','taxi_202202.csv','taxi_202203.csv','taxi_202204.csv','taxi_202205.csv','taxi_202206.csv','taxi_202207.csv','taxi_202208.csv','taxi_202209.csv','taxi_202210.csv','taxi_202211.csv','taxi_202212.csv']

# %%
filelist
# Out:
# ['taxi_202201.csv',
#  'taxi_202201.csv',
#  'taxi_202202.csv',
#  'taxi_202203.csv',
#  'taxi_202204.csv',
#  'taxi_202205.csv',
#  'taxi_202206.csv',
#  'taxi_202207.csv',
#  'taxi_202208.csv',
#  'taxi_202209.csv',
#  'taxi_202210.csv',
#  'taxi_202211.csv',
#  'taxi_202212.csv']

# %% [markdown]
# ## Ignoring Warnings

# %%
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %% [markdown]
# ## Appending 12 Data Sets in to one Data Frame

# %%
df_append = pd.DataFrame()
for file in filelist:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)

# %%
df_append.shape
# Out:
# (3022306, 27)

# %%
df_append.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3022306 entries, 0 to 3022305
# Data columns (total 27 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   OBJECTID                int64
#  1   TRIPTYPE                object
#  2   PROVIDERNAME            float64
#  3   FAREAMOUNT              float64
#  4   GRATUITYAMOUNT          float64
#  5   SURCHARGEAMOUNT         float64
#  6   EXTRAFAREAMOUNT         float64
#  7   TOLLAMOUNT              float64
#  8   TOTALAMOUNT             float64
#  9   PAYMENTTYPE             int64
#  10  ORIGINCITY              object
#  11  ORIGINSTATE             object
#  12  ORIGINZIP               object
#  13  DESTINATIONCITY         object
#  14  DESTINATIONSTATE        object
#  15  DESTINATIONZIP          object
#  16  MILEAGE                 float64
#  17  DURATION                float64
#  18  ORIGIN_BLOCK_LATITUDE   float64
#  19  ORIGIN_BLOCK_LONGITUDE  float64
#  20  ORIGIN_BLOCKNAME        object
# ...

# %%
df_append.isnull().sum()
# Out:
# OBJECTID                        0
# TRIPTYPE                        0
# PROVIDERNAME              3022306
# FAREAMOUNT                 160092
# GRATUITYAMOUNT             160092
# SURCHARGEAMOUNT            160092
# EXTRAFAREAMOUNT            160092
# TOLLAMOUNT                 160092
# TOTALAMOUNT                     2
# PAYMENTTYPE                     0
# ORIGINCITY                      0
# ORIGINSTATE                  4935
# ORIGINZIP                       0
# DESTINATIONCITY                 0
# DESTINATIONSTATE             5197
# DESTINATIONZIP                  0
# MILEAGE                         0
# DURATION                       86
# ORIGIN_BLOCK_LATITUDE      473219
# ORIGIN_BLOCK_LONGITUDE     473219
# ORIGIN_BLOCKNAME           473219
# DESTINATION_BLOCK_LAT      679893
# DESTINATION_BLOCK_LONG     679893
# DESTINATION_BLOCKNAME      679893
# AIRPORT                   2424630
# ORIGINDATETIME_TR               0
# DESTINATIONDATETIME_TR          0
# dtype: int64

# %% [markdown]
# ## Dropping PROVIDERNAME and AIRPORT columns which has most of the Nan values

# %%
df_append = df_append.drop(['PROVIDERNAME','AIRPORT'], axis=1)

# %%
df_append.isnull().sum()
# Out:
# OBJECTID                       0
# TRIPTYPE                       0
# FAREAMOUNT                160092
# GRATUITYAMOUNT            160092
# SURCHARGEAMOUNT           160092
# EXTRAFAREAMOUNT           160092
# TOLLAMOUNT                160092
# TOTALAMOUNT                    2
# PAYMENTTYPE                    0
# ORIGINCITY                     0
# ORIGINSTATE                 4935
# ORIGINZIP                      0
# DESTINATIONCITY                0
# DESTINATIONSTATE            5197
# DESTINATIONZIP                 0
# MILEAGE                        0
# DURATION                      86
# ORIGIN_BLOCK_LATITUDE     473219
# ORIGIN_BLOCK_LONGITUDE    473219
# ORIGIN_BLOCKNAME          473219
# DESTINATION_BLOCK_LAT     679893
# DESTINATION_BLOCK_LONG    679893
# DESTINATION_BLOCKNAME     679893
# ORIGINDATETIME_TR              0
# DESTINATIONDATETIME_TR         0
# dtype: int64

# %% [markdown]
# ## Heatmap to visualize missing values

# %%
sns.heatmap(df_append.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>
